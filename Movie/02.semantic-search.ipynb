# %% [markdown]
# # Semantic Search

# %% [markdown]
# ## 필요한 패키지 설치

# %%
# !pip install -q boto3
# !pip install -q requests
# !pip install -q requests-aws4auth
# !pip install -q opensearch-py
# !pip install -q tqdm
# !pip install -q boto3

# %% [markdown]
# ## 데이터 준비

# %%
import pandas as pd

movies_raw_df = pd.read_csv("./data/movies.csv", low_memory=False)
movies_raw_df.head(10)
# Out:
# title          genre             year  date   rating  vote_count  plot                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               main_act                                                        supp_act                                                                                                                                                                       page_url                                                   img_url
# ...ing         멜로/로맨스|드라마        2003  11.28  8.89    1577        평범한 고등학생 민아. 자신이 보기에도 유난히 철이 없어 보이는 엄마와 단 둘이 살고 있는 민아는 그러나, 내성적인 성격탓에 변변한 친구하나 없는 학교생활이 재미 없기만 하다. 그런 학교 생활에서 유일한 재미거리는 학교 앞에서 교통정리를 하는 약간 정신이 이상한 기수. 전설처럼 들려오는, 자기 학교 선배와 기수간에 있었던 아릿한 로맨스 스토리를 듣고서 민아는 자신에게도 그런 운명적인 사랑이 다가올 것이라는 근거없는 기대속에 살고 있다. 보통 때와 같은 평범한 어느날, 엄마와 살고 있는 빌라 아래층에 건들거리는 대학생 영재가 이사를 들어오게 되고, 이웃사촌이라는 핑계로 자신에게 건들대는 영재가 영 마뜩찮고 귀찮기만 하다. 첫 만남부터가 꼬였던 영재와 민아. 아무것도 모르는 엄마는 민아에게 드디어 남자친구가 생겼다며 일찌감치 앞서 나가고, 그런 엄마와 같이 장단을 맞추는 영재. 사사건건 토닥토닥 시비를 걸어오는 영재에게 어느덧 민아가 말리기 시작하는데.  임수정|김래원|이미숙                                                     최덕문|이성경|김지영|윤덕현|이유정                                                                                                                                                            https://movie.naver.com/movie/bi/mi/basic.nhn?code=36957   https://movie-phinf.pstatic.net/20111222_70/1324521558483aEPka_JPEG/movie_image.jpg?type=m77_110_2     1
# 옥자             모험|액션|드라마         2017  6.29   8.45    18488       강원도 산골 소녀 ‘미자’(안서현)에게 옥자는 1 년 간 함께 자란 둘도 없는 친구이자 소중한 가족이다. 자연 속에서 평화롭게 지내던 어느 날, 글로벌 기업 ‘미란도’가 나타나 갑자기 옥자를 뉴욕으로 끌고가고, 할아버지(변희봉)의 만류에도 미자는 무작정 옥자를 구하기 위해 위험천만한 여정에 나선다. 극비리에 옥자를 활용한 ‘슈퍼돼지 프로젝트’를 추진 중인 ‘미란도 코퍼레이션’의 CEO ‘루시 미란도’(틸다 스윈튼), 옥자를 이용해 제2의 전성기를 꿈꾸는 동물학자 ‘죠니’(제이크 질렌할), 옥자를 앞세워 또 다른 작전을 수행하려는 비밀 동물 보호 단체 ALF까지. 각자의 이권을 둘러싸고 옥자를 차지하려는 탐욕스러운 세상에 맞서, 옥자를 구출하려는 미자의 여정은 더욱 험난해져 간다.                                                                                                   틸다 스윈튼|폴 다노|안서현                                                 변희봉|스티븐 연|릴리 콜린스|윤제문|셜리 헨더슨|다니엘 헨셜|데본 보스틱|최우식|지안카를로 에스포지토|제이크 질렌할|이정은|최희서|장지웅|박기선|윤경호|조완기|한이진|곽진석                                                                              https://movie.naver.com/movie/bi/mi/basic.nhn?code=143435  https://movie-phinf.pstatic.net/20170904_126/1504516484057JACUa_JPEG/movie_image.jpg?type=m77_110_2    1
한 캐서린 건을 도와 국가를 상대로 목숨 건 변호를 시작한다. 정의를 위해, 진실을 위해 국가를 배신한 사람들 유죄인가? 무죄인가?                                                                                                                                                           키이라 나이틀리|랄프 파인즈|맷 스미스                                           매튜 구드|리스 이판|아담 바크리|인디라 바르마|캐서린 켈리|콘레스 힐|미안나 버링|제레미 노덤|피터 기네스                                                                                                                   https://movie.naver.com/movie/bi/mi/basic.nhn?code=146433  https://movie-phinf.pstatic.net/20191107_272/1573116849363c2aSQ_JPEG/movie_image.jpg?type=m77_110_2    1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ..
# 무명인            미스터리|스릴러|액션       2014  5.29   8.39    563         사랑하는 아내와 행복한 삶을 살고 있는 이시가미(니시지마 히데토시 분). 그는 결혼 후 아내와 처음으로 함께 생일을 맞이할 설렘을 안고 집으로 향한다. 부푼 마음을 안고 집에 돌아온 이시가미는 싸늘한 시체가 된 부인을 발견하고 충격에 빠진다. 하지만 죽었다고 생각했던 아내에게서 전화가 걸려오고, 그는 믿을 수 없는 상황에 더 큰 혼란에 빠지고 만다. 사건의 진실을 파헤치던 이시가미는 취재차 도쿄를 방문한 한국 기자 강지원(김효진 분)의 도움을 받게 되지만 자신의 기억이 모두 조작되었다는 사실과 함께 거대한 음모에 휘말리게 되는데… 죽은 아내의 시체 그리고 한 통의 전화. 모든 것이 무너지고, 기억들이 사라진다!                                                                                                                                          니시지마 히데토시|김효진                                                   마키 요코|하마다 마나부|나카무라 유리|이부 마사토|이경영|박동하|토다 마사히로|반도 타쿠미|박해준|나하나                                                                                                                    https://movie.naver.com/movie/bi/mi/basic.nhn?code=96910   https://movie-phinf.pstatic.net/20140515_291/1400130157056WpBMk_JPEG/movie_image.jpg?type=m77_110_2    1
# 무문관            다큐멘터리             2018  4.19   8.28    151         마주서는 48개의 관문. 그 문(門)은 이 세상에 존재하지 않는다. 하지만 그 문을 통과하면 용(龍)이 되고 부처가 된다. 세상의 모든 시비가 끊어진 이곳에서 그 문을 여는데 주어진 기간은 1 일! 자물쇠 채운 선방 안, 11명의 스님들이 자신과의 숭고한 싸움을 시작한다. 과연 몇 명의 스님들이 1 일 후 그 문을 열고 나올 것인가?                                                                                                                                                                                                                                                                                                        정보없음                                                            정보없음                                                                                                                                                                           https://movie.naver.com/movie/bi/mi/basic.nhn?code=173459  https://movie-phinf.pstatic.net/20180316_16/1521165812607AxttB_JPEG/movie_image.jpg?type=m77_110_2     1
# 무민 더 무비        애니메이션|코미디|가족      2015  8.13   7.89    188         귀염지수 2 %, 포근한 매력의 ‘무민’ 소년 같은 순수함을 간직한 ‘무민 파파’ 따뜻한 무민 가족의 버팀목 ‘무민 마마’ 못 말리는 ‘무민’의 여친 ‘스노크메이든’ 무민 가족은 골짜기를 벗어나 남쪽 바다로 여행을 떠난다. 두근두근 콩닥콩닥 신나는 바캉스 지금부터 시작~! 그.러.나 이들을 기다리고 있는 것은 예측불허 초특급 사건?! 올 여름, 엉뚱하지만 사랑스러운 무민 가족의 바캉스 대소동이 시작된다!                                                                                                                                                                                                                                                                크리스토퍼 검머러스|마리아 시드|매츠 랑백카|알마 포이스티|라그니 그뢴블롬|C.G. 웬젤|카를 크리스티안 룬드만  러셀 토비|트레이시 앤 오버맨|나다니엘 파커|루스 깁슨|스테파니 위닉키|도미닉 프리스비|필립 스몰리코스키                                                                                                                     https://movie.naver.com/movie/bi/mi/basic.nhn?code=131099  https://movie-phinf.pstatic.net/20150804_29/1438652246363m08TM_JPEG/movie_image.jpg?type=m77_110_2     1
# 무민가족의 한여름 대소동  애니메이션|가족|판타지      2013  6.20   7.00    7           무민 계곡의 평온한 여름날은 화산폭발로 인한 홍수로 난장판이 된다.무민가족의 집 대부분이 물에 잠기고 어떻게 해야할지 고민하고 있던 그들의 앞에 수상한 집 한채가 떠내려 온다. 그곳으로 피신한 무민가족은 정체불명의 인물과 마주치게 되고 곧 그 집의 숨겨진 비밀을 알게된다. 한편 나무 위에서 휴식을 취하던 무민과 스노크메이든은 가족들과 헤어져 배회하다가 엉뚱한 오해를 받고 쫓기게 되며, 리틀마이 역시 생각지도 못한 사건 사고들에 휘말리며 기상천외한 모험의 세계로 빠져들게 되는데...                                                                                                                                                                                                                    오우티 알라넨|스티그 호프메이어                                               부오코 호바타|타넬리 마켈라|자스퍼 파코넨|엘자 사이시오                                                                                                                                                https://movie.naver.com/movie/bi/mi/basic.nhn?code=111002  https://movie-phinf.pstatic.net/20130612_38/1371004024846hiW8D_JPEG/movie_image.jpg?type=m77_110_2     1
# 힛쳐             공포|액션|범죄|스릴러|드라마  2007  8.01   4.46    981         {미 교통부(U.S. Dep rtment of Tr nsport tion)에 따르면 매년 42, 여 명이 고속도로에서 사망한다고 한다} 캠퍼스 커플인 '그레이스'와 '짐'은 방학을 맞아 둘만의 여행을 떠난다. 어두운 밤, 굵은 빗줄기 속에 외딴 도로를 달리던 이들의 차량은 도로 한가운데 서 있던 남자를 미처 발견하지 못해 교통사고를 낼 뻔 하고 미안한 마음에 이 낯선 남자를 태워주게 된다. 그러나 차에 태운 남자 '존 라이더'가 자신들의 생명을 위협하는 위험한 인물임을 알게 되면서, 이들의 즐거웠던 휴가는 순식간에 끔찍한 공포로 뒤바뀌게 되는데...                                                                                                                                                                             숀 빈                                                             소피아 부시|잭카리 나이튼|닐 맥도프                                                                                                                                                           https://movie.naver.com/movie/bi/mi/basic.nhn?code=64991   https://movie-phinf.pstatic.net/20111222_38/13244797654616p0OR_JPEG/movie_image.jpg?type=m77_110_2     1
# Name: count, Length: 11951, dtype: int64

# %% [markdown]
# ## OpenSearch에 데이터 인덱싱하기

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth
import boto3
import json

credentials = boto3.Session().get_credentials()
auth = AWSV4SignerAuth(credentials, region="us-east-1")

aos_host = "search-bedrock-opensearch-6gczufsfv5pp76bvtsd62qkrxu.aos.us-east-1.on.aws"


aos_client = OpenSearch(
    hosts=[{"host": aos_host, "port": 443}],
    http_auth=auth,
    use_ssl=True,
    verify_certs=True,
    connection_class=RequestsHttpConnection,
    timeout=600,
)

# %% [markdown]
# ## 임베딩 모델 준비하기

# %%
s = b'{"transient":{"plugins.ml_commons.only_run_on_ml_node": false}}'
aos_client.cluster.put_settings(body=s)
# Out:
# {'acknowledged': True,
#  'persistent': {},
#  'transient': {'plugins': {'ml_commons': {'only_run_on_ml_node': 'false'}}}}

# %% [markdown]
# ### Bedrock Titan Embedding G1 모델 Register
#
# request 패키지를 이용해본다.

# %%
# Bedrock Titan Embeddings G1 - Text Connector 생성

import requests

connector_payload = {
    "name": "Connector to Bedrock Titan Embeddings G1 - Text",
    "description": "The connector to Bedrock Titan Embeddings G1 - Text",
    "version": 1,
    "protocol": "aws_sigv4",
    "parameters": {
        "region": "us-east-1",
        "service_name": "bedrock",
        "input_docs_processed_step_size": 2,
    },
    "credential": {"roleArn": "arn:aws:iam::236241703319:role/OpenSearchForBedrockRole"},
    "actions": [
        {
            "action_type": "predict",
            "method": "POST",
            "url": "https://bedrock-runtime.us-east-1.amazonaws.com/model/amazon.titan-embed-text-v1/invoke",
            "headers": {"content-type": "application/json", "x-amz-content-sha256": "required"},
            "request_body": '{ "inputText": "${parameters.inputText}" }',
            "pre_process_function": '\n    StringBuilder builder = new StringBuilder();\n    builder.append("\\"");\n    String first = params.text_docs[0];\n    builder.append(first);\n    builder.append("\\"");\n    def parameters = "{" +"\\"inputText\\":" + builder + "}";\n    return  "{" +"\\"parameters\\":" + parameters + "}";',
            "post_process_function": '\n      def name = "sentence_embedding";\n      def dataType = "FLOAT32";\n      if (params.embedding == null || params.embedding.length == 0) {\n        return params.message;\n      }\n      def shape = [params.embedding.length];\n      def json = "{" +\n                 "\\"name\\":\\"" + name + "\\"," +\n                 "\\"data_type\\":\\"" + dataType + "\\"," +\n                 "\\"shape\\":" + shape + "," +\n                 "\\"data\\":" + params.embedding +\n                 "}";\n      return json;\n    ',
        }
    ],
}

base_url = (
    "https://search-bedrock-opensearch-6gczufsfv5pp76bvtsd62qkrxu.aos.us-east-1.on.aws/_plugins/_ml"
)

# Send the request
response = requests.post(
    base_url + "/connectors/_create",
    auth=auth,
    json=connector_payload,
)

# Print the response
print(response.text)
# Out:
# {"connector_id":"iD1Qjo4B1FbzESchRpWr"}

# %%
obj = json.loads(response.text)
connector_id = obj["connector_id"]

# %% [markdown]
# Register Model Group

# %%
register_model_group_payload = {
    "name": "Bedrock Models",
    "description": "This is a model group for Amazon Bedrock remote model.",
}

# Send the request
response = requests.post(
    base_url + "/model_groups/_register",
    auth=auth,
    json=register_model_group_payload,
)

# Print the response
print(response.text)
# Out:
# {"model_group_id":"EVZQjo4B5vU2gwgcSrgY","status":"CREATED"}

# %%
obj = json.loads(response.text)
model_group_id = obj["model_group_id"]

# %% [markdown]
# Register Model

# %%
register_model_payload = {
    "name": "Bedrock text embedding model",
    "function_name": "remote",
    "model_group_id": model_group_id,
    "description": "This is Bedrock Titan Embeddings G1 - Text model",
    "connector_id": "flaMhY4B5vU2gwgcXTu4",
}

# Send the request
response = requests.post(
    base_url + "/models/_register",
    auth=auth,
    json=register_model_payload,
)

# Print the response
print(response.text)
# Out:
# {"task_id":"iT1Qjo4B1FbzESchTZWD","status":"CREATED","model_id":"ij1Qjo4B1FbzESchTZWr"}

# %%
obj = json.loads(response.text)
model_id = obj["model_id"]
print(model_id)
# Out:
# ij1Qjo4B1FbzESchTZWr

# %% [markdown]
# Deploy Model

# %%
deploy_model_payload = {}

# Send the request
response = requests.post(
    base_url + "/models/" + model_id + "/_deploy",
    auth=auth,
    json=deploy_model_payload,
)

# Print the response
print(response.text)
# Out:
# {"task_id":"ElZQjo4B5vU2gwgcUbgf","task_type":"DEPLOY_MODEL","status":"COMPLETED"}

# %% [markdown]
# Test the model

# %%
test_model_payload = {"parameters": {"inputText": "바다에서 펼쳐지는 해적들의 꿈과 모험 이야기"}}

# Send the request
response = requests.post(
    base_url + "/models/" + "kGhNiI4BnEOV7ezVxzHF" + "/_predict",
    auth=auth,
    json=test_model_payload,
)

# Print the response
display(json.loads(response.text))
# Out:
# {'inference_results': [{'output': [{'name': 'sentence_embedding',
#      'data_type': 'FLOAT32',
#      'shape': [1536],
#      'data': [0.0075683594,
#       -0.80078125,
#       0.0054016113,
#       0.23828125,
#       0.68359375,
#       0.2109375,
#       -0.12207031,
#       -0.0005187988,
#       -0.94140625,
#       -0.84375,
#       0.12011719,
#       0.59375,
#       -0.17382812,
#       1.1953125,
#       0.19335938,
#       -0.40429688,
#       -0.23242188,
#       -0.14550781,
#       -0.42382812,
#       -0.38476562,
#       0.41601562,
#       -0.5234375,
#       -0.15625,
#       1.203125,
#       -0.20996094,
#       0.25976562,
#       0.35546875,
#       -1.21875,
#       -0.029907227,
#       0.18554688,
#       -0.83203125,
#       1.0703125,
#       0.37109375,
#       0.31054688,
#       -0.04663086,
#       -0.33398438,
#       -0.13769531,
#       -0.44335938,
#       0.18066406,
#       -0.056884766,
#       -0.73828125,
#       -0.74609375,
#       -0.24707031,
#       0.47070312,
#       -0.056640625,
#       0.48046875,
#       0.75390625,
#       0.032714844,
#       0.4375,
#       0.31445312,
#       0.15917969,
#       0.42382812,
#       0.18261719,
#       -0.40820312,
#       -0.3828125,
#       -0.114746094,
#       0.09667969,
#       -0.5390625,
#       -0.890625,
#       -0.10253906,
#       -0.095214844,
#       0.6875,
#       -0.01171875,
#       0.7734375,
#       0.07470703,
#       0.22753906,
#       0.34960938,
#       -0.32421875,
#       0.34375,
#       0.15527344,
#       -0.107910156,
#       -0.19628906,
#       0.056640625,
#       -0.81640625,
#       0.14746094,
#       0.125,
#       0.09326172,
#       0.22167969,
#       0.5625,
#       -0.9609375,
#       0.095703125,
#       -1.3359375,
#       0.078125,
#       -0.55859375,
#       0.07128906,
#       -1.265625,
#       -0.00049972534,
#       -0.21484375,
#       0.00010871887,
#       0.91015625,
#       0.34960938,
#       -0.11279297,
#       0.7734375,
#       0.31835938,
#       -0.19042969,
#       -0.8203125,
#       -0.390625,
#       0.0058898926,
#       0.5390625,
#       -0.36132812,
#       -1.03125,
#       0.48046875,
#       0.115234375,
#       0.7109375,
#       -0.66015625,
#       0.5859375,
#       0.17773438,
#       0.375,
#       -0.37109375,
#       0.41796875,
#       -0.87109375,
#       -0.17578125,
#       0.13378906,
#       0.12207031,
#       -0.053955078,
#       0.09082031,
#       0.41601562,
#       -0.04345703,
#       0.3359375,
#       -0.265625,
#       -0.83203125,
#       0.609375,
#       -0.20117188,
#       -0.053222656,
#       0.4296875,
#       -0.25585938,
#       0.52734375,
#       -0.19921875,
#       0.11669922,
#       -0.12158203,
#       -0.62890625,
#       0.020263672,
#       -0.36328125,
#       0.1953125,
#       -0.8984375,
#       -0.000579834,
#       -0.25976562,
#       0.38476562,
#       -0.22265625,
#       0.625,
#       0.98046875,
#       0.20507812,
#       0.41992188,
#       0.40039062,
#       0.34179688,
#       0.4375,
#       0.49804688,
#       2.6345253e-05,
#       -0.020385742,
#       -0.53515625,
#       -0.08886719,
#       0.36132812,
#       0.4375,
#       1.125,
#       0.66015625,
#       -0.052734375,
#       -0.5703125,
#       -0.34570312,
#       -0.53515625,
#       -0.2109375,
#       -0.890625,
#       0.111816406,
#       0.72265625,
#       -0.23632812,
#       -0.18652344,
#       -0.079589844,
#       0.53125,
#       0.47851562,
#       1.3125,
#       0.51171875,
#       -0.28515625,
#       0.12695312,
#       -0.79296875,
#       0.10107422,
#       0.5390625,
#       -0.36132812,
#       0.32617188,
#       -0.22949219,
#       0.043945312,
#       0.4375,
#       -0.62109375,
#       -0.18847656,
#       -0.80859375,
#       -0.38476562,
#       0.26757812,
#       -0.45507812,
#       -0.20410156,
#       -1.2578125,
#       -0.31445312,
#       -0.028564453,
#       -0.57421875,
#       -1.171875,
#       -0.61328125,
#       0.27929688,
#       ...]}],
#    'status_code': 200}]}

# %%
print(model_id)
# Out:
# ij1Qjo4B1FbzESchTZWr

# %% [markdown]
# ## Ingest Pipeline 생성

# %%
# aos_client.ingest.get_pipeline(id="embedding_pipeline")
aos_client.indices.delete(index="movies_semantic_index")
# Out:
# {'acknowledged': True}

# %%
pipeline = {
    "description": "An neural search pipeline - titan embedding g1 text",
    "processors": [
        {
            "text_embedding": {
                "model_id": model_id,
                "field_map": {
                    "plot": "plot_vector",
                },
            }
        },
        {
            "text_embedding": {
                "model_id": model_id,
                "field_map": {
                    "title": "title_vector",
                },
            }
        },
        {
            "text_embedding": {
                "model_id": model_id,
                "field_map": {
                    "genre": "genre_vector",
                },
            }
        },
    ],
}

pipeline_id = "embedding_pipeline"
aos_client.ingest.put_pipeline(id=pipeline_id, body=pipeline)
# Out:
# {'acknowledged': True}

# %%
aos_client.ingest.get_pipeline(id=pipeline_id)
# Out:
# {'embedding_pipeline': {'description': 'An neural search pipeline - titan embedding g1 text',
#   'processors': [{'text_embedding': {'model_id': 'ij1Qjo4B1FbzESchTZWr',
#      'field_map': {'plot': 'plot_vector'}}},
#    {'text_embedding': {'model_id': 'ij1Qjo4B1FbzESchTZWr',
#      'field_map': {'title': 'title_vector'}}},
#    {'text_embedding': {'model_id': 'ij1Qjo4B1FbzESchTZWr',
#      'field_map': {'genre': 'genre_vector'}}}]}}

# %% [markdown]
# ### Index 생성

# %%
movies_semantic_index = {
    "settings": {
        "max_result_window": 15000,
        "analysis": {"analyzer": {"analysis-nori": {"type": "nori", "stopwords": "_korean_"}}},
        "index.knn": True,
        "default_pipeline": pipeline_id,
        "index.knn.space_type": "cosinesimil",
    },
    "mappings": {
        "properties": {
            "date": {"type": "float"},
            "genre": {
                "type": "text",
            },
            "img_url": {
                "type": "text",
                "fields": {"keyword": {"type": "keyword", "ignore_above": 256}},
            },
            "main_act": {
                "type": "text",
                "fields": {"keyword": {"type": "keyword", "ignore_above": 256}},
            },
            "page_url": {
                "type": "text",
                "fields": {"keyword": {"type": "keyword", "ignore_above": 256}},
            },
            "plot": {
                "type": "text",
            },
            "rating": {"type": "float"},
            "supp_act": {
                "type": "text",
                "fields": {"keyword": {"type": "keyword", "ignore_above": 256}},
            },
            "title": {
                "type": "text",
                "fields": {"keyword": {"type": "keyword", "ignore_above": 256}},
            },
            "vote_count": {"type": "long"},
            "year": {"type": "long"},
            "title_vector": {
                "type": "knn_vector",
                "dimension": 1536,
                "method": {"name": "hnsw", "space_type": "l2", "engine": "faiss"},
                "store": True,
            },
            "plot_vector": {
                "type": "knn_vector",
                "dimension": 1536,
                "method": {"name": "hnsw", "space_type": "l2", "engine": "faiss"},
                "store": True,
            },
            "genre_vector": {
                "type": "knn_vector",
                "dimension": 1536,
                "method": {"name": "hnsw", "space_type": "l2", "engine": "faiss"},
                "store": True,
            },
        }
    },
}

# %%
index_name = "movies_semantic_index"

# aos_client.indices.delete(index=index_name)
aos_client.indices.create(index=index_name, body=movies_semantic_index)
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'index': 'movies_semantic_index'}

# %%
aos_client.indices.get(index=index_name)
# Out:
# {'movies_semantic_index': {'aliases': {},
#   'mappings': {'properties': {'date': {'type': 'float'},
#     'genre': {'type': 'text'},
#     'genre_vector': {'type': 'knn_vector',
#      'store': True,
#      'dimension': 1536,
#      'method': {'engine': 'faiss',
#       'space_type': 'l2',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'img_url': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'main_act': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'page_url': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'plot': {'type': 'text'},
#     'plot_vector': {'type': 'knn_vector',
#      'store': True,
#      'dimension': 1536,
#      'method': {'engine': 'faiss',
#       'space_type': 'l2',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'rating': {'type': 'float'},
#     'supp_act': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'title': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'title_vector': {'type': 'knn_vector',
#      'store': True,
#      'dimension': 1536,
#      'method': {'engine': 'faiss',
#       'space_type': 'l2',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'vote_count': {'type': 'long'},
#     'year': {'type': 'long'}}},
#   'settings': {'index': {'replication': {'type': 'DOCUMENT'},
#     'number_of_shards': '5',
#     'provided_name': 'movies_semantic_index',
#     'knn.space_type': 'cosinesimil',
#     'max_result_window': '15000',
#     'default_pipeline': 'embedding_pipeline',
#     'knn': 'true',
#     'creation_date': '1711784614319',
#     'analysis': {'analyzer': {'analysis-nori': {'type': 'nori',
#        'stopwords': '_korean_'}}},
#     'number_of_replicas': '2',
#     'uuid': 'kb6fFGcpQuOVowfk9PCw8A',
#     'version': {'created': '136327827'}}}}}

# %% [markdown]
# ## Load data

# %%
# Try ingest one document

# payload = {
#     "title": "파묘",
#     "genre": "공포",
#     "image_url": "http://pamyo.com",
#     "page_url": "http://pamyo.com",
#     "main_act": "최민식, 류해진",
#     "plot": "아주 무서운 이야기",
#     "rating": "10.0",
#     "supp_act": "안기범, 권혁수",
#     "vote_count": "100",
#     "year": "2024",
# }

# aos_client.index(index=index_name, body=payload)

# %%
from tqdm import tqdm
from opensearchpy import helpers

json_data = movies_raw_df.to_json(orient="records", lines=True)
docs = json_data.split("\n")[:-1]  # To remove the last empty line


def _generate_data():
    for doc in docs:
        yield {"_index": index_name, "_source": doc}


succeeded = []
failed = []
for success, item in helpers.parallel_bulk(
    aos_client, actions=_generate_data(), chunk_size=10, thread_count=2, queue_size=2
):
    if success:
        succeeded.append(item)
    else:
        failed.append(item)


# Ingest the DataFrame
# for idx, row in tqdm(movies_raw_df.iterrows()):
#     aos_client.index(index="movies_default_index", body=row.to_dict(), id=idx)
# Out:
# ---------------------------------------------------------------------------
# BulkIndexError                            Traceback (most recent call last)
# Cell In[244], line 15
#      13 succeeded = []
#      14 failed = []
# ---> 15 for success, item in helpers.parallel_bulk(
#      16     aos_client, actions=_generate_data(), chunk_size=10, thread_count=2, queue_size=2
#      17 ):
#      18     if success:
#      19         succeeded.append(item)
#
# File ~/anaconda3/lib/python3.11/site-packages/opensearchpy/helpers/actions.py:487, in parallel_bulk(client, actions, thread_count, chunk_size, max_chunk_bytes, queue_size, expand_action_callback, raise_on_exception, raise_on_error, ignore_status, *args, **kwargs)
#     484 pool = BlockingPool(thread_count)
#     486 try:
# --> 487     for result in pool.imap(
#     488         lambda bulk_chunk: list(
#     489             _process_bulk_chunk(
#     490                 client,
#     491                 bulk_chunk[1],
#     492                 bulk_chunk[0],
#     493                 raise_on_exception,
#     494                 raise_on_error,
#     495                 ignore_status,
#     496                 *args,
#     497                 **kwargs
#     498             )
#     499         ),
#     500         _chunk_actions(
#     501             actions, chunk_size, max_chunk_bytes, client.transport.serializer
#     502         ),
#     503     ):
#     504         for item in result:
#     505             yield item
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~/anaconda3/lib/python3.11/site-packages/opensearchpy/helpers/actions.py:488, in parallel_bulk.<locals>.<lambda>(bulk_chunk)
#     484 pool = BlockingPool(thread_count)
#     486 try:
#     487     for result in pool.imap(
# --> 488         lambda bulk_chunk: list(
#     489             _process_bulk_chunk(
#     490                 client,
#     491                 bulk_chunk[1],
#     492                 bulk_chunk[0],
#     493                 raise_on_exception,
#     494                 raise_on_error,
#     495                 ignore_status,
#     496                 *args,
#     497                 **kwargs
#     498             )
#     499         ),
#     500         _chunk_actions(
#     501             actions, chunk_size, max_chunk_bytes, client.transport.serializer
#     502         ),
#     503     ):
#     504         for item in result:
#     505             yield item
#
# File ~/anaconda3/lib/python3.11/site-packages/opensearchpy/helpers/actions.py:273, in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, ignore_status, *args, **kwargs)
#     266 else:
#     267     gen = _process_bulk_chunk_success(
#     268         resp=resp,
#     269         bulk_data=bulk_data,
#     270         ignore_status=ignore_status,
#     271         raise_on_error=raise_on_error,
#     272     )
# --> 273 for item in gen:
#     274     yield item
#
# File ~/anaconda3/lib/python3.11/site-packages/opensearchpy/helpers/actions.py:202, in _process_bulk_chunk_success(resp, bulk_data, ignore_status, raise_on_error)
#     199         yield ok, {op_type: item}
#     201 if errors:
# --> 202     raise BulkIndexError("%i document(s) failed to index." % len(errors), errors)
#
# BulkIndexError: ('1 document(s) failed to index.', [{'index': {'_index': 'movies_semantic_index', '_id': None, 'status': 400, 'error': {'type': 'illegal_argument_exception', 'reason': 'Invalid JSON in payload'}, 'data': '{"title":"\\uac8c\\uc774\\ubd09\\ubc15\\ub4504: RUMOR","genre":"\\ub4dc\\ub77c\\ub9c8|\\ucf54\\ubbf8\\ub514|\\uacf5\\ud3ec","year":2015,"date":7.11,"rating":8.33,"vote_count":12,"plot":"[OPEN] \\uac10\\ub3c5 : \\ubc94, \\uc7a5\\ub974 : \\ub4dc\\ub77c\\ub9c8 \\uce5c\\uad6c\\uc640 \\ud568\\uaed8 \\uacfc\\uc81c\\ub97c \\ud558\\uace0 \\uc788\\ub294 \\ud55c\\ub3c4\\uc758 \\uc790\\ucde8\\ubc29\\uc73c\\ub85c \\uc220 \\ucde8\\ud55c \\uc560\\uc778\\uc774 \\uac11\\uc791\\uc2a4\\ub808 \\ucc3e\\uc544\\uc628\\ub2e4. \\uadf8\\ub807\\uac8c \\uc2dc\\uc791\\ub418\\ub294 \\ud55c\\ub3c4\\u00b7\\uce5c\\uad6c\\u00b7\\uc560\\uc778\\uc758 3\\uac01 \\uc904\\ub2e4\\ub9ac\\uae30. [FMSM] \\uac10\\ub3c5 : \\uace0\\uc218\\ubbf8, \\uc7a5\\ub974: \\ub4dc\\ub77c\\ub9c8 \\"\\uc5b4\\ub290 \\uac8c\\uc774\\uc758 \\ud558\\ub8fb\\ubc24\\"\\uc744 \\ubcf4\\uc5ec\\uc90c\\uc73c\\ub85c\\uc368
# %%
# Refresh the index to make the changes visible
aos_client.indices.refresh(index=index_name)
# Out:
# {'_shards': {'total': 15, 'successful': 15, 'failed': 0}}

# %%
res = aos_client.search(index=index_name, body={"query": {"match_all": {}}})
print("Records found: %d " % res["hits"]["total"]["value"])
count = aos_client.count(index=index_name)
print(count)

# %% [markdown]
# ## Neural Search

# %%
# query_text = "우주에서 펼쳐지는 전쟁 이야기"
# query_text = "동물이 나오는 만화"
# query_text = "영웅들이 힘을 합쳐 빌런을 물리치고 세상을 구한다"
query_text = "큰 자연 재해가 발생하고 인류는 위기를 맞는다"

# %%
semantic_query = {
    "size": 30,
    "_source": {"excludes": ["title_vector, plot_vector, genre_vector"]},
    "query": {
        "bool": {
            # "must": [
            "should": [
                {
                    "neural": {
                        "title_vector": {
                            "query_text": query_text,
                            "model_id": model_id,
                            "k": 30,
                        }
                    }
                },
                {
                    "neural": {
                        "plot_vector": {
                            "query_text": query_text,
                            "model_id": model_id,
                            "k": 30,
                        }
                    }
                },
                {
                    "neural": {
                        "genre_vector": {
                            "query_text": query_text,
                            "model_id": model_id,
                            "k": 30,
                        }
                    }
                },
            ]
        }
    },
}

# %%
res = aos_client.search(index=index_name, body=semantic_query)
query_result = []
for hit in res["hits"]["hits"]:
    row = [
        hit["_id"],
        hit["_score"],
        hit["_source"]["title"],
        hit["_source"]["plot"],
        hit["_source"]["genre"],
        hit["_source"]["rating"],
    ]
    query_result.append(row)

query_result_df = pd.DataFrame(
    data=query_result, columns=["_id", "_score", "title", "plot", "genre", "rating"]
)
display(query_result_df)
# Out:
#                      _id    _score                  title  \
# 0   xT1Rjo4B1FbzESchYpha  0.010095          콜로니: 인류 최후의 날
# 1   nj1Qjo4B1FbzEScht5YT  0.009939  세상의 종말을 예언하는 소년: 프로디지
# 2   DT1Tjo4B1FbzESch3KBi  0.009832           콜로니:지구 최후의 날
# 3   1lZTjo4B5vU2gwgc8MJ7  0.009655           헬벤더스: 최후의 성전
# 4   1z1Tjo4B1FbzESchy5-C  0.009586                인투 더 스톰
# 5   zj1Ujo4B1FbzESchE6Bx  0.009466         디 엔드: 인류 최후의 날
# 6   az1Ujo4B1FbzESchSqE3  0.009463             신밧드의 7대 모험
# 7   aFZUjo4B5vU2gwgcIMPM  0.009400     마진 콜: 24시간, 조작된 진실
# 8   6j1Tjo4B1FbzESch0Z8h  0.009282           존은 끝에 가서 죽는다
# 9   5j1Tjo4B1FbzESch0Z8h  0.009208                   조난자들
# 10  zFZXjo4B5vU2gwgcmM1H  0.009116             007 어나더 데이
# 11  7lZQjo4B5vU2gwgc-Lna  0.009114                 12 솔져스
# 12  UlZRjo4B5vU2gwgcFroQ  0.009078                레지던트 데블
# 13  S1ZQjo4B5vU2gwgcb7g8  0.009066                시체들의 새벽
# 14  Xz1Tjo4B1FbzESch8aDO  0.009040           혹성탈출: 반격의 서막
# 15  Zj1Qjo4B1FbzESchopYY  0.008962          명탐정 코난:전율의 악보
# 16  mVZQjo4B5vU2gwgc4bmu  0.008930          지구 침공의 날 2019
# 17  WVZQjo4B5vU2gwgcdbhu  0.008909      이누야시키 : 히어로 VS 빌런
# 18  YVZRjo4B5vU2gwgcG7r5  0.008879                  마일 22
# 19  xj1Tjo4B1FbzESchxZ_g  0.008860                위키드 블러드
# 20  Dj1Sjo4B1FbzESchLJtP  0.008835  다이노소어 어드벤처: 백악기 공룡대백과
# 21  5T1Rjo4B1FbzESchHJfS  0.008824             매드맥스: 로드 워
# 22  5lZQjo4B5vU2gwgcobjs  0.008802                 마탄의 사수
# 23  C1ZTjo4B5vU2gwgc_sPQ  0.008790             기브 엠 헬, 말론
# 24  7z1Qjo4B1FbzESchf5VC  0.008780                 47미터 2
# 25  Xz1Ujo4B1FbzESchQ6Ge  0.008769                    스니치
# 26  KT1Qjo4B1FbzESchjZaY  0.008739                 다커 나이트
# 27  Lj1Qjo4B1FbzESchkZZg  0.008671                   더 스쿨
# 28  4lZUjo4B5vU2gwgcScPl  0.008624       시체 전문 처리반 - 스머글러
# 29  xj1Qjo4B1FbzESchcZVj  0.008581              엄마 바람피게하기
#
#                                                  plot          genre  rating
# 0   우주에서 화물을 나르고 지구로 돌아가던 우주선 오셀롯은 불의의 사고로 소행성에 불시...      모험|SF|스릴러    1.24
# 1   2 24년 8월 15일, 전 세계인이 동시에 의식을 잃는 사건이 발생한다. 일종의 ...        드라마|스릴러    1.74
# 2   2144년, 갑작스러운 지구 온난화 이후 빙하기가 찾아왔다. 가까스로 살아남은 생존...      액션|SF|스릴러    6.30
# 3   인류의 종말을 목전에 둔 순간, 잔혹한 악마들에게 맞서기 위해 그들이 나섰다! 악마...         공포|스릴러    5.54
# 4   갑작스런 기상 이변으로 발생한 수퍼 토네이도가 오클라호마의 실버톤을 덮쳐 쑥대밭으로...         액션|스릴러    8.23
# 5   2 년 지기 친구들인 펠릭스, 사라, 휴고, 마리벨, 라파, 세르히오는 과거 우발적...         스릴러|모험    3.92
# 6   세계 최대의 유조선 ‘아카바’호가 해적들에 납치당하자, 선박회사 ‘카마란’의 회장 ...      액션|판타지|모험    2.20
# 7   갑작스런 인원 감축으로 퇴직 통보를 받는 리스크 관리 팀장 에릭은 자신의 부하직원 ...        스릴러|드라마    7.76
# 8   감히 비교 불가능의 찌질한 루저인 존과 데이빗은 속칭 ‘간장’으로 불리는 정체불명의...     판타지|공포|코미디    6.67
# 9   여행이 스릴러가 된다! 홀로 깊은 산속 주인 없는 펜션을 찾아온 허세 여행자 ‘상진...       미스터리|스릴러    7.24
# 10  모든 것이 베일에 싸인 동토의 제국 북한, 그곳에도 평화를 원하는 온건파의 노력은 ...      액션|모험|스릴러    5.76
# 11  전 세계가 목격한 사상 최악의 테러 발생 15일 후, '미치(크리스 헴스워스)'는 ...      액션|드라마|전쟁    8.12
# 12  원인불명의 질병이 급속도로 번져 수많은 사람들이 감염되어 좀비처럼 인간을 마구잡이로...      액션|공포|스릴러    4.00
# 13  원인을 알 수 없는 바이러스로 인해 수많은 사람들이 사람의 살을 뜯어 먹는 괴물로 ...      공포|스릴러|SF    8.25
# 14  치명적인 바이러스 그 후 1 년, 시저가 이끄는 진화한 유인원들은 자신들의 삶의 터...  액션|드라마|SF|스릴러    8.53
# 15  음악가만을 노린 연쇄살인사건이 발생하고, 피해자들은 모두 유명한 피아니스트가 설립한...     애니메이션|서스펜스    8.25
# 16  평화로운 한때, 어느 날 갑자기 정체를 알 수 없는 외계 생물체들이 지구를 침공한다...          SF|액션    1.00
# 17  “나는 아무런 쓸모가 없는 인간인 걸까” 회사와 가정에서 소외된 중년남 ‘이누야시키...      액션|SF|드라마    7.42
# 18  군사, 외교의 사각지대에서 임무를 수행하는 실패율 제로의 비밀조직 ‘오버워치’. 그...      액션|모험|스릴러    7.43
# 19  부모를 잃은 1 대 소녀 해나, 남은 가족을 지키기 위한 기발한 음모를 꾸민다! 해...     액션|드라마|스릴러    5.52
# 20  작지만 용감한 파키, 진정한 리더로 거듭나다! 7천만 년 전, 따뜻한 알래스카에 살...       애니메이션|모험    6.91
# 21  좀비 바이러스가 급격히 퍼져 문명은 파괴되고 황무지로 변해버린 세상. 살아남은 소수...          액션|SF    2.09
# 22  정기적으로 열리는 사격대회에서 우승을 하면 지역 산림감독관의 딸, 아가테와 결혼함과...   공연실황|드라마|스릴러    7.00
# 23  말론은 온 가족이 살해당한 후, 형사에서 살인 청부업자로 직업을 바꾸고 자신의 가족...      액션|범죄|스릴러    6.50
# 24  물에 잠긴 고대 마야의 수중도시 '시발바'를 향해 짜릿한 동굴 다이빙에 나선 '미아...         공포|스릴러    6.99
# 25  아들 제이슨이 마약 거래를 했다는 억울한 누명을 쓰고 체포되었다는 소식을 들은 존(...     액션|드라마|스릴러    8.45
# 26  슬로안 카터는 지병으로 인해 최근에 눈이 보이지 않게 되었다. 그녀의 아버지는 주말...         공포|스릴러    4.50
# 27  의사인 '에이미'는 병원에서 아이들이 하나 둘씩 죽어가는 것을 경험한다. 같은 병원...    공포|스릴러|미스터리    1.00
# 28  배우 지망생이자 아르바이트로 생활을 하고 있는 25세 ‘료스케’는 배우의 꿈에 좌절...         액션|스릴러    7.00
# 29  다른 여자와 바람을 피우는 걸로 모자라 결혼식까지 몰래 올려버린 아빠. 딸 ‘예리’...        코미디|드라마    4.67

# %%
## Lexical (keyword) Search한 결과와 비교

# %%
lexical_query = {
    "size": 30,
    "query": {
        "multi_match": {
            "query": query_text,
            "fields": ["title", "plot", "genre"],
        }
    },
}

# %%
res = aos_client.search(index=index_name, body=lexical_query)
query_result = []
for hit in res["hits"]["hits"]:
    row = [
        hit["_id"],
        hit["_score"],
        hit["_source"]["title"],
        hit["_source"]["plot"],
        hit["_source"]["genre"],
        hit["_source"]["rating"],
    ]
    query_result.append(row)

query_result_df = pd.DataFrame(
    data=query_result, columns=["_id", "_score", "title", "plot", "genre", "rating"]
)
display(query_result_df)
# Out:
#                      _id     _score                  title  \
# 0   nz1Tjo4B1FbzESchu59v  18.694748             엣지 오브 투모로우
# 1   cT1Qjo4B1FbzESchqZZI  16.245892        미용실 : 특별한 서비스 3
# 2   vj1Sjo4B1FbzESchD5qS  15.608034                현상금 사냥꾼
# 3   S1ZWjo4B5vU2gwgcBslp  14.668031                 북극의 눈물
# 4   IVZSjo4B5vU2gwgcqb_g  13.097054                   감옥풍운
# 5   KD1Ujo4B1FbzESchhqI3  12.455068                      헬
# 6   MT1Wjo4B1FbzESch6qmK  12.117457                     샤크
# 7   41ZVjo4B5vU2gwgc48j2  12.016863                    강적들
# 8   Pj1Tjo4B1FbzESchPZ6i  11.316657                   화산고래
# 9   AD1Tjo4B1FbzESchhZ9m  10.261786                  미 앤 유
# 10  yFZRjo4B5vU2gwgcProj  10.184997          아기곰 보보 구출 대작전
# 11  h1ZTjo4B5vU2gwgcgcH1  10.118706                   몬스터즈
# 12  o1ZTjo4B5vU2gwgc48Ii   9.440714          특수경찰 : 스페셜 ID
# 13  DFZSjo4B5vU2gwgc_8A2   9.118987  아이돌 마스터 무비 : 빛의 저편으로!
# 14  AVZWjo4B5vU2gwgcmctV   8.872890                 룸 투 렌트
# 15  HT1Ujo4B1FbzESchLqHR   8.802778                 부도리의 꿈
# 16  vVZWjo4B5vU2gwgchMq7   8.558678                    히어로
# 17  4lZUjo4B5vU2gwgcScPl   8.540972       시체 전문 처리반 - 스머글러
# 18  RT1Wjo4B1FbzESchLqfh   8.371422                     호튼
# 19  Sz1Wjo4B1FbzESchmqhQ   8.326241               린다 린다 린다
# 20  vz1Wjo4B1FbzESchvqjX   8.315164     크리스탈 요정 지스쿼드 - 시리즈
# 21  vj1Wjo4B1FbzESchvqjX   8.301374           크리스탈 요정 지스쿼드
# 22  dT1Qjo4B1FbzESch_JfI   8.273560                걷기 좋은 날
# 23  xj1Tjo4B1FbzESchE51q   8.264875                   유닛 7
# 24  vlZRjo4B5vU2gwgciruq   8.204783                 나를 찾아서
# 25  V1ZUjo4B5vU2gwgcbcTU   8.174607                    카르고
# 26  lD1Qjo4B1FbzESchs5ax   8.167257                   사일런스
# 27  6VZTjo4B5vU2gwgcpMEe   8.042448               시도니아의 기사
# 28  fVZXjo4B5vU2gwgcGsx4   8.025053           달은 어디에 떠 있는가
# 29  flZWjo4B5vU2gwgcGsly   7.841846                   온 에어
#
#                                                  plot            genre  rating
# 0   가까운 미래, 미믹이라 불리는 외계 종족의 침략으로 인류는 멸망 위기를 맞는다. 빌...            액션|SF    8.95
# 1   동네의 한적한 미용실, 여성 디자이너 세정마저 일을 그만 두자 가게는 큰 위기를 맞...           멜로/로맨스   10.00
# 2   얼어붙은 불모의 땅 서부에서 살아가던 와이엇(제임스 랜슨)과 사무엘(조쉬 펙) 형제...         서부|액션|모험    4.00
# 3   MBC 창사 47주년 특별기획 '북극의 눈물'은 '세계 극지의 해'를 맞아 벼랑 끝...            다큐멘터리    8.20
# 4   평생을 바른 생활 사나이로 살아오던 '노가요'(양가휘)는 아버지를 때린 이들과 싸우...           드라마|액션    7.42
# 5   때는 2 16년. 지금으로부터 4년 후, 모든 생명의 근원이었던 태양의 흑점 폭발로...        SF|공포|스릴러    6.45
# 6   무소불위, 절대권력에 막강 카리스마를 가진 상어 대부 돈 리노. 하지만 그에게도 말...  애니메이션|가족|코미디|모험    7.04
# 7   수호는 대통령인 아버지(강민국)의 생일에도 어김없이 말썽을 일으키고, 보다 못한 영...           드라마|액션    8.00
# 8   2 7 년, 인류는 대지진과 화산폭발로 위기를 맞게 되었다. 자연재해로 인해 무정부...            애니메이션    6.63
# 9   이 시대의 거장이 만든 아주 특별한 음악 성장 영화! “사랑하는 나의 동생, 널 위...           드라마|가족    7.93
# 10  작은 생쥐 앤디, 레미, 다람쥐 아저씨, 빵집 토끼 아저씨 등은 모두 신비한 숲 허...  애니메이션|모험|가족|뮤지컬    7.53
# 11  2 9년, 태양계에서 외계생명체의 존재가능성을 발견한 우주 탐사선이 외계 샘플을 채...    드라마|공포|SF|스릴러    5.98
# 12  8년 동안 조직에 잠입하여 비밀리에 임무를 수행해온 진자룡(견자단). 어느 날, 조...        액션|범죄|스릴러    5.69
# 13  어딘가 허름한 건물 3층에 위치한 연예 기획사 765프로덕션. 그곳에는 신출내기 프...            애니메이션    7.85
# 14  시나리오 작가로 성공하겠다는 부푼 꿈을 안고 런던 유학길에 오른 알리. 주방보조, ...              코미디    7.93
# 15  아름다운 이하토브 숲에서 태어난 고양이 부도리는 부모님과 여동생 네리와 함께 행복하...    애니메이션|판타지|드라마    5.09
# 16  엉뚱하지만 천재적 사건 해결력을 자랑하는 행동파 검사 쿠리우(기무라 타쿠야). 도쿄...              드라마    7.96
# 17  배우 지망생이자 아르바이트로 생활을 하고 있는 25세 ‘료스케’는 배우의 꿈에 좌절...           액션|스릴러    7.00
# 18  ‘눌~루랄라 정글’ 에서 가장 큰 몸집을 가졌지만 티끌보다도 작고 여린 마음을 가진...  애니메이션|모험|코미디|가족    8.15
# 19  시바사키 고등학교에선 문화제 준비가 한창이다. 고교생활 마지막을 장식할 문화제에 참...      코미디|드라마|뮤지컬    7.83
# 20  세명의 1 대 소녀들이 성장기를 겪으면서 자신의 존재가치를 깨닫는다. 지구에서 2 ...            애니메이션    9.75
# 21  세명의 1 대 소녀들이 성장기를 겪으면서 자신의 존재가치를 깨닫는다. 지구에서 2 ...         애니메이션|가족    9.83
# 22  내 인생의 마지막 시간일지는 모르는 이 순간, 미치도록 걷기 좋은 날이다! 여행을 ...              드라마    5.00
# 23  '1992 세비야 세계 박람회'를 앞두고 도시를 장악한 마약갱단을 척결하라는 임무를...        드라마|범죄|액션    4.20
# 24  힘든 살림에 쌍둥이 아들까지 태어나 '윌리엄'은 깊은 고민 끝에 두 아이 중, 한 ...              드라마    6.70
# 25  지구 종말 이후, 인류의 마지막 희망은 새로운 행성 ‘레아’로 떠나는 것. 레아로 ...      SF|미스터리|스릴러    5.85
# 26  갑자기 알 수 없는 존재가 세상의 모든 소리를 집어 삼키고, 소리 내는 모든 인류는...               공포    5.35
# 27  대화불능의 이생물 가우나에 의해 파괴된 태양계. 간신히 살아남은 극소수의 인류는 소...            애니메이션    7.75
# 28  일본 이름 타다오, 한국 이름은 강충남. 그는 동창이 운영하는 택시 회사에서 운전기...   코미디|드라마|멜로/로맨스    7.96
# 29  SBC방송사와 드라마 제작사, 작가, 연예 기획사를 배경으로 제작 현장의 병폐와 기...          드라마|코미디    9.13

# %% [markdown]
# ## Hybrid Search를 해보자

# %% [markdown]
# ### Search Pipeline 생성

# %%
search_pipeline_payload = {
    "description": "Post processor for hybrid search",
    "phase_results_processors": [
        {
            "normalization-processor": {
                "normalization": {"technique": "min_max"},
                "combination": {
                    "technique": "arithmetic_mean",
                    "parameters": {"weights": [0.3, 0.7]},
                },
            }
        }
    ],
}

search_pipeline_id = "search_pipeline"

# %%
# GET /my-nlp-index/_search?search_pipeline=nlp-search-pipeline
hybrid_query = {
    "size": 30,
    "_source": {"exclude": ["passage_embedding"]},
    "query": {
        "hybrid": {
            "queries": [
                {"match": {"plot": {"query": query_text}}},
                {
                    "neural": {
                        "plot_vector": {
                            "query_text": query_text,
                            "model_id": model_id,
                            "k": 30,
                        }
                    }
                },
            ]
        }
    },
    "search_pipeline": {
        "description": "Post processor for hybrid search",
        "phase_results_processors": [
            {
                "normalization-processor": {
                    "normalization": {"technique": "min_max"},
                    "combination": {
                        "technique": "arithmetic_mean",
                        "parameters": {"weights": [0.5, 0.5]},
                    },
                }
            }
        ],
    },
}

# %%
res = aos_client.search(index=index_name, body=hybrid_query)
query_result = []
for hit in res["hits"]["hits"]:
    row = [
        hit["_id"],
        hit["_score"],
        hit["_source"]["title"],
        hit["_source"]["plot"],
        hit["_source"]["genre"],
        hit["_source"]["rating"],
    ]
    query_result.append(row)

query_result_df = pd.DataFrame(
    data=query_result, columns=["_id", "_score", "title", "plot", "genre", "rating"]
)
display(query_result_df)
# Out:
#                      _id    _score                     title  \
# 0   KD1Ujo4B1FbzESchhqI3  0.632655                         헬
# 1   Yj1Wjo4B1FbzESchoKhj  0.568196                    불편한 진실
# 2   Aj1Qjo4B1FbzESch2pfB  0.537729                      유랑지구
# 3   kj1Vjo4B1FbzESchpqVk  0.522603                      2012
# 4   nz1Tjo4B1FbzESchu59v  0.500000                엣지 오브 투모로우
# 5   qj1Ujo4B1FbzESchXaFM  0.500000                      월드워Z
# 6   XFZYjo4B5vU2gwgcKM_z  0.447231                    타이탄 AE
# 7   dD1Rjo4B1FbzESch9Zpj  0.429835                      지오스톰
# 8   cT1Qjo4B1FbzESchqZZI  0.428060           미용실 : 특별한 서비스 3
# 9   XVZRjo4B5vU2gwgca7uv  0.415472                      퍼스트맨
# 10  UlZRjo4B5vU2gwgcFroQ  0.409803                   레지던트 데블
# 11  vj1Sjo4B1FbzESchD5qS  0.409321                   현상금 사냥꾼
# 12  S1ZWjo4B5vU2gwgcBslp  0.381707                    북극의 눈물
# 13  RD1Rjo4B1FbzESch5ppL  0.376753                   외계 대 침공
# 14  1z1Ujo4B1FbzESchwKJy  0.376625                        생존
# 15  az1Ujo4B1FbzESchSqE3  0.366169                신밧드의 7대 모험
# 16  7VZTjo4B5vU2gwgc9cLX  0.363732                        감기
# 17  ZVZWjo4B5vU2gwgcuMsx  0.358250                     일본 침몰
# 18  Pj1Sjo4B1FbzESchOZvp  0.357208                 렘넌트: 생존자들
# 19  oj1Wjo4B1FbzESchXadE  0.351354                       선샤인
# 20  GlZUjo4B5vU2gwgcBMPM  0.348276                  넥스트 투모로우
# 21  FD1Sjo4B1FbzESchgZww  0.347481            인디펜던스 데이: 리써전스
# 22  iz1Ujo4B1FbzESchU6HJ  0.340809  에코 플래닛 3D : 지구 구출 특급 대작전
# 23  eD1Sjo4B1FbzESch-J3k  0.337453                     쏠라 어택
# 24  jlZRjo4B5vU2gwgcfbtm  0.335840                    LA 대지진
# 25  IVZSjo4B5vU2gwgcqb_g  0.335556                      감옥풍운
# 26  8D1Qjo4B1FbzESchf5VC  0.335104            48시간: 지구 최후의 날
# 27  plZSjo4B5vU2gwgcL73H  0.325953                     더 웨이브
# 28  FT1Wjo4B1FbzESchIaeI  0.323123                        지구
# 29  AFZXjo4B5vU2gwgcSM3j  0.319345             진도 10.5 미국 침몰
#
#                                                  plot              genre  \
# 0   때는 2 16년. 지금으로부터 4년 후, 모든 생명의 근원이었던 태양의 흑점 폭발로...          SF|공포|스릴러
# 1   기상이변으로 인한 심각한 환경 위기! 킬리만자로, 몬타나 주 빙하국립공원, 콜롬비아...              다큐멘터리
# 2   가까운 미래, 태양계 소멸 위기를 맞은 지구는 영하 7 도의 이상 기후와 함께 목성...                 SF
# 3   고대 마야 문명에서부터 끊임없이 회자되어 온 인류 멸망. 2 12년, 저명한 과학자...   액션|드라마|스릴러|SF|모험
# 4   가까운 미래, 미믹이라 불리는 외계 종족의 침략으로 인류는 멸망 위기를 맞는다. 빌...              액션|SF
# 5   전 세계 이상 기류… 거대한 습격이 시작된다! 의문의 항공기 습격, 국가별 입국 전...   드라마|스릴러|SF|액션|모험
# 6   멀고도 광활한 은하계로의 여행은 이제 인류에게 일상적이고 자유로운 하나의 생활이 되...  애니메이션|모험|전쟁|SF|가족
# 7   가까운 미래, 기후변화로 인해 지구에 갖가지 자연재해가 속출한다. 세계 정부 연합은...          액션|SF|스릴러
# 8   동네의 한적한 미용실, 여성 디자이너 세정마저 일을 그만 두자 가게는 큰 위기를 맞...             멜로/로맨스
# 9   이제껏 누구도 경험하지 못한 세계에 도전한 우주비행사 닐(라이언 고슬링)은, 거대한...             SF|드라마
# 10  원인불명의 질병이 급속도로 번져 수많은 사람들이 감염되어 좀비처럼 인간을 마구잡이로...          액션|공포|스릴러
# 11  얼어붙은 불모의 땅 서부에서 살아가던 와이엇(제임스 랜슨)과 사무엘(조쉬 펙) 형제...           서부|액션|모험
# 12  MBC 창사 47주년 특별기획 '북극의 눈물'은 '세계 극지의 해'를 맞아 벼랑 끝...              다큐멘터리
# 13  어느 날 갑자기 지구에 외계 생명체가 나타나 인간들을 죽이고 지구의 광물을 채굴하기...         SF|스릴러|드라마
# 14  지구 탄생 후 그 구석구석 완벽하게 적응해온 생명체, 그건 바로 인류다. 영하 5 ...              다큐멘터리
# 15  세계 최대의 유조선 ‘아카바’호가 해적들에 납치당하자, 선박회사 ‘카마란’의 회장 ...          액션|판타지|모험
# 16  호흡기로 감염, 감염속도 초당 3.4명, 치사율 1 %의 유례 없는 최악의 바이러스...          드라마|모험|액션
# 17  일본 스루가만에서 강도 1 을 넘는 엄청난 파괴력의 대지진이 발생한다. 이어 도쿄,...      SF|드라마|모험|스릴러
# 18  역대 최고 규모의 태양 폭발로 전 지구가 어둠에 휩싸이고, 대통령과 고위 관료는 사...          액션|드라마|SF
# 19  {태양은 죽어가고 인류는 멸망의 위기에 처해있다. 7년 전, 태양을 살리려던 이카루...             SF|스릴러
# 20  아이슬란드의 ‘헤클라 산’에서 엄청난 규모의 화산분출이 시작되었다! 그와 동시에 거...              액션|SF
# 21  다시, 그들이 온다! 2 년 전 최악의 우주 전쟁을 치른 지구. 재건을 위해 힘쓴 ...           액션|모험|SF
# 22  “에너지 괴물이 지구를 덮치면 이 세상은 멸망할거야. 지구의 목소리를 듣는 자만이 ...              애니메이션
# 23  태양에서 갑자기 터져 나온 역사상 최대 규모 태양풍 강타로 지구가 화염에 휩싸이게 ...             SF|스릴러
# 24  정유 회사의 사장 리터는 LA 국립공원 근처에 새 시추 스테이션을 열어 기름을 빼내...          액션|모험|드라마
# 25  평생을 바른 생활 사나이로 살아오던 '노가요'(양가휘)는 아버지를 때린 이들과 싸우...             드라마|액션
# 26  어느 날 갑자기 세상이 사라졌다! 하루아침에 모두 붕괴되어 버린 건물들과 사라져버린...                코미디
# 27  시속 6 km의 쓰나미, 생존 대피시간 단 1 분! 북유럽을 덮친 사상최악의 재난실...         액션|드라마|스릴러
# 28  생명의 땅을 찾아 나선 동물 가족들의 지구 대장정 어드벤처. 약 46억년 전, 한 ...        다큐멘터리|가족|모험
# 29  제1부. 미국 시애틀 도심부에 대형 지진이 발생한다. 지진학자인 사만사는 이 지진의...                드라마
#
#     rating
# 0     6.45
# 1     8.79
# 2     5.89
# 3     7.61
# 4     8.95
# 5     8.22
# 6     7.92
# 7     7.44
# 8    10.00
# 9     6.96
# 10    4.00
# 11    4.00
# 12    8.20
# 13    4.22
# 14   10.00
# 15    2.20
# 16    6.95
# 17    3.39
# 18    7.00
# 19    7.57
# 20    2.83
# 21    7.25
# 22    9.41
# 23    3.25
# 24    4.22
# 25    7.42
# 26    7.88
# 27    6.39
# 28    8.60
# 29    5.70
